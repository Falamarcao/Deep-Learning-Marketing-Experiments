# %% [markdown]
# # Transfer Learning
#
# Most of the time you won't want to train a whole convolutional network yourself. Modern ConvNets training on huge datasets like ImageNet take weeks on multiple GPUs. Instead, most people use a pretrained network either as a fixed feature extractor, or as an initial network to fine tune. In this notebook, you'll be using [VGGNet](https://arxiv.org/pdf/1409.1556.pdf) trained on the [ImageNet dataset](http://www.image-net.org/) as a feature extractor. Below is a diagram of the VGGNet architecture.
#
# <img src="assets/cnnarchitecture.jpg" width=700px>
#
# VGGNet is great because it's simple and has great performance, coming in second in the ImageNet competition. The idea here is that we keep all the convolutional layers, but replace the final fully connected layers with our own classifier. This way we can use VGGNet as a feature extractor for our images then easily train a simple classifier on top of that. What we'll do is take the first fully connected layer with 4096 units, including thresholding with ReLUs. We can use those values as a code for each image, then build a classifier on top of those codes.
#
# You can read more about transfer learning from [the CS231n course notes](http://cs231n.github.io/transfer-learning/#tf).
#
# ## Pretrained VGGNet
#
# We'll be using a pretrained network from https://github.com/machrisaa/tensorflow-vgg. Make sure to clone this repository to the directory you're working from. You'll also want to rename it so it has an underscore instead of a dash.
#
# ```
# git clone https://github.com/machrisaa/tensorflow-vgg.git tensorflow_vgg
# ```
#
# This is a really nice implementation of VGGNet, quite easy to work with. The network has already been trained and the parameters are available from this link. **You'll need to clone the repo into the folder containing this notebook.** Then download the parameter file using the next cell.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm

vgg_dir = 'tensorflow_vgg/'
# Make sure vgg exists
if not isdir(vgg_dir):
    raise Exception("VGG directory doesn't exist!")

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(vgg_dir + "vgg16.npy"):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='VGG16 Parameters') as pbar:
        urlretrieve(
            'https://s3.amazonaws.com/content.udacity-data.com/nd101/vgg16.npy',
            vgg_dir + 'vgg16.npy',
            pbar.hook)
else:
    print("Parameter file already exists!")
# Out:
# Parameter file already exists!

# %% [markdown]
# ## ConvNet Codes
#
# Below, we'll run through all the images in our dataset and get codes for each of them. That is, we'll run the images through the VGGNet convolutional layers and record the values of the first fully connected layer. We can then write these to a file for later when we build our own classifier.
#
# Here we're using the `vgg16` module from `tensorflow_vgg`. The network takes images of size $224 \times 224 \times 3$ as input. Then it has 5 sets of convolutional layers. The network implemented here has this structure (copied from [the source code](https://github.com/machrisaa/tensorflow-vgg/blob/master/vgg16.py)):
#
# ```
# self.conv1_1 = self.conv_layer(bgr, "conv1_1")
# self.conv1_2 = self.conv_layer(self.conv1_1, "conv1_2")
# self.pool1 = self.max_pool(self.conv1_2, 'pool1')
#
# self.conv2_1 = self.conv_layer(self.pool1, "conv2_1")
# self.conv2_2 = self.conv_layer(self.conv2_1, "conv2_2")
# self.pool2 = self.max_pool(self.conv2_2, 'pool2')
#
# self.conv3_1 = self.conv_layer(self.pool2, "conv3_1")
# self.conv3_2 = self.conv_layer(self.conv3_1, "conv3_2")
# self.conv3_3 = self.conv_layer(self.conv3_2, "conv3_3")
# self.pool3 = self.max_pool(self.conv3_3, 'pool3')
#
# self.conv4_1 = self.conv_layer(self.pool3, "conv4_1")
# self.conv4_2 = self.conv_layer(self.conv4_1, "conv4_2")
# self.conv4_3 = self.conv_layer(self.conv4_2, "conv4_3")
# self.pool4 = self.max_pool(self.conv4_3, 'pool4')
#
# self.conv5_1 = self.conv_layer(self.pool4, "conv5_1")
# self.conv5_2 = self.conv_layer(self.conv5_1, "conv5_2")
# self.conv5_3 = self.conv_layer(self.conv5_2, "conv5_3")
# self.pool5 = self.max_pool(self.conv5_3, 'pool5')
#
# self.fc6 = self.fc_layer(self.pool5, "fc6")
# self.relu6 = tf.nn.relu(self.fc6)
# ```
#
# So what we want are the values of the first fully connected layer, after being ReLUd (`self.relu6`). To build the network, we use
#
# ```
# with tf.Session() as sess:
#     vgg = vgg16.Vgg16()
#     input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
#     with tf.name_scope("content_vgg"):
#         vgg.build(input_)
# ```
#
# This creates the `vgg` object, then builds the graph with `vgg.build(input_)`. Then to get the values from the layer,
#
# ```
# feed_dict = {input_: images}
# codes = sess.run(vgg.relu6, feed_dict=feed_dict)
# ```

# %%
import os

import numpy as np
import tensorflow as tf

from tensorflow_vgg import vgg16
from tensorflow_vgg import utils

# %%
data_dir = 'Data/'
contents = os.listdir(data_dir)
classes = [each for each in contents if os.path.isdir(data_dir + each)]

# %% [markdown]
# Below I'm running images through the VGG network in batches.
#
# > **Exercise:** Below, build the VGG network. Also get the codes from the first fully connected layer (make sure you get the ReLUd values).

# %%
# Set the batch size higher if you can fit in in your GPU memory
batch_size = 64
codes_list = []
labels = []
batch = []

codes = None

with tf.Session() as sess:
    
    # TODO: Build the vgg network here
    vgg = vgg16.Vgg16()
    input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
    with tf.name_scope("content_vgg"):
        vgg.build(input_)

    for each in classes:
        print("Starting {} images".format(each))
        class_path = data_dir + each
        files = os.listdir(class_path)
        for ii, file in enumerate(files, 1):
            # Add images to the current batch
            # utils.load_image crops the input images for us, from the center
            img = utils.load_image(os.path.join(class_path, file))
            batch.append(img.reshape((1, 224, 224, 3)))
            labels.append(each)
            
            # Running the batch through the network to get the codes
            if ii % batch_size == 0 or ii == len(files):
                
                # Image batch to pass to VGG network
                images = np.concatenate(batch)
                
                # TODO: Get the values from the relu6 layer of the VGG network
                feed_dict = {input_: images}
                codes_batch = sess.run(vgg.relu6, feed_dict=feed_dict)
                
                # Here I'm building an array of the codes
                if codes is None:
                    codes = codes_batch
                else:
                    codes = np.concatenate((codes, codes_batch))
                
                # Reset to start building the next batch
                batch = []
                print('{} images processed'.format(ii))
# Out:
# C:\Users\Falamarcao\Desktop\brand_recognition\tensorflow_vgg\vgg16.npy
# npy file loaded
# build model started
# build model finished: 0s
# Starting cocacola images
# C:\Users\Falamarcao\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 64 images processed
# 128 images processed
# 192 images processed
# 256 images processed
# 320 images processed
# 384 images processed
# 448 images processed
# 512 images processed
# 576 images processed
# 640 images processed
# 645 images processed
# Starting guaranaantarctica images
# 64 images processed
# 128 images processed
# 192 images processed
# 256 images processed
# 320 images processed
# 384 images processed
# 424 images processed
# Starting pepsi images
# 64 images processed
# 128 images processed
# 179 images processed

# %%
# write codes to file
with open('codes', 'w') as f:
    codes.tofile(f)
    
# write labels to file
import csv
with open('labels', 'w') as f:
    writer = csv.writer(f, delimiter='\n')
    writer.writerow(labels)

# %% [markdown]
# ## Building the Classifier
#
# Now that we have codes for all the images, we can build a simple classifier on top of them. The codes behave just like normal input into a simple neural network. Below I'm going to have you do most of the work.

# %%
# read codes and labels from file
import csv

with open('labels') as f:
    reader = csv.reader(f, delimiter='\n')
    labels = np.array([each for each in reader if len(each) > 0]).squeeze()
with open('codes') as f:
    codes = np.fromfile(f, dtype=np.float32)
    codes = codes.reshape((len(labels), -1))

# %% [markdown]
# ### Data prep
#
# As usual, now we need to one-hot encode our labels and create validation/test sets. First up, creating our labels!
#
# > **Exercise:** From scikit-learn, use [LabelBinarizer](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelBinarizer.html) to create one-hot encoded vectors from the labels.

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
lb.fit(labels)
labels_vecs = lb.transform(labels) # Your one-hot encoded labels array here

# %% [markdown]
# Now you'll want to create your training, validation, and test sets. An important thing to note here is that our labels and data aren't randomized yet. We'll want to shuffle our data so the validation and test sets contain data from all classes. Otherwise, you could end up with testing sets that are all one class. Typically, you'll also want to make sure that each smaller set has the same the distribution of classes as it is for the whole data set. The easiest way to accomplish both these goals is to use [`StratifiedShuffleSplit`](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html) from scikit-learn.
#
# You can create the splitter like so:
# ```
# ss = StratifiedShuffleSplit(n_splits=1, test_size=0.2)
# ```
# Then split the data with
# ```
# splitter = ss.split(x, y)
# ```
#
# `ss.split` returns a generator of indices. You can pass the indices into the arrays to get the split sets. The fact that it's a generator means you either need to iterate over it, or use `next(splitter)` to get the indices. Be sure to read the [documentation](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html) and the [user guide](http://scikit-learn.org/stable/modules/cross_validation.html#random-permutations-cross-validation-a-k-a-shuffle-split).
#
# > **Exercise:** Use StratifiedShuffleSplit to split the codes and labels into training, validation, and test sets.

# %%
from sklearn.model_selection import StratifiedShuffleSplit
ss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, train_size=None)

"""função 'split' retorna um 'generator', portanto é necessario iterar 
ou usar a função 'next' para retornar os valores dos indices"""
train_idx, val_idx = next(ss.split(codes, labels))

#separando os indíces em dois (validacao e teste)
##determina o meio
half_val_len = int(len(val_idx)/2)
##para finalmente separar
val_idx, test_idx = val_idx[:half_val_len], val_idx[half_val_len:]

"""atribuí às variáveis os valores. 'codes' vem da função split
e 'labels_vecs' é foi estabelecido na celula anterior"""
train_x, train_y = codes[train_idx], labels_vecs[train_idx]
val_x, val_y = codes[val_idx], labels_vecs[val_idx]
test_x, test_y = codes[test_idx], labels_vecs[test_idx]

# %%
print("Train shapes (x, y):", train_x.shape, train_y.shape)
print("Validation shapes (x, y):", val_x.shape, val_y.shape)
print("Test shapes (x, y):", test_x.shape, test_y.shape)
# Out:
# Train shapes (x, y): (998, 4096) (998, 3)
# Validation shapes (x, y): (125, 4096) (125, 3)
# Test shapes (x, y): (125, 4096) (125, 3)

# %% [markdown]
# If you did it right, you should see these sizes for the training sets:
#
# ```
# Train shapes (x, y): (2936, 4096) (2936, 5)
# Validation shapes (x, y): (367, 4096) (367, 5)
# Test shapes (x, y): (367, 4096) (367, 5)
# ```

# %% [markdown]
# ### Classifier layers
#
# Once you have the convolutional codes, you just need to build a classfier from some fully connected layers. You use the codes as the inputs and the image labels as targets. Otherwise the classifier is a typical neural network.
#
# > **Exercise:** With the codes and labels loaded, build the classifier. Consider the codes as your inputs, each of them are 4096D vectors. You'll want to use a hidden layer and an output layer as your classifier. Remember that the output layer needs to have one unit for each class and a softmax activation function. Use the cross entropy to calculate the cost.

# %%
inputs_ = tf.placeholder(tf.float32, shape=[None, codes.shape[1]])
labels_ = tf.placeholder(tf.int64, shape=[None, labels_vecs.shape[1]])

# TODO: Classifier layers and operations

fully = tf.contrib.layers.fully_connected(inputs= inputs_,
                                           num_outputs=512,
                                           activation_fn=tf.nn.relu)

logits = tf.contrib.layers.fully_connected(inputs=fully,
                                           num_outputs=labels_vecs.shape[1],
                                           activation_fn=None
                                          ) # output layer logits

cross_entropy = tf.nn.softmax_cross_entropy_with_logits(
    labels=labels_,
    logits=logits
)

cost = tf.reduce_mean(cross_entropy)  # cross entropy loss

optimizer = tf.train.AdamOptimizer().minimize(cost) # training optimizer

# Operations for validation/test accuracy
predicted = tf.nn.softmax(logits)
correct_pred = tf.equal(tf.argmax(predicted, 1), tf.argmax(labels_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %% [markdown]
# ### Batches!
#
# Here is just a simple way to do batches. I've written it so that it includes all the data. Sometimes you'll throw out some data at the end to make sure you have full batches. Here I just extend the last batch to include the remaining data.

# %%
def get_batches(x, y, n_batches=10):
    """ Return a generator that yields batches from arrays x and y. """
    batch_size = len(x)//n_batches
    
    for ii in range(0, n_batches*batch_size, batch_size):
        # If we're not on the last batch, grab data with size batch_size
        if ii != (n_batches-1)*batch_size:
            X, Y = x[ii: ii+batch_size], y[ii: ii+batch_size] 
        # On the last batch, grab the rest of the data
        else:
            X, Y = x[ii:], y[ii:]
        # I love generators
        yield X, Y

# %% [markdown]
# ### Training
#
# Here, we'll train the network.
#
# > **Exercise:** So far we've been providing the training code for you. Here, I'm going to give you a bit more of a challenge and have you write the code to train the network. Of course, you'll be able to see my solution if you need help. Use the `get_batches` function I wrote before to get your batches like `for x, y in get_batches(train_x, train_y)`. Or write your own!

# %%
epochs = 20
iteration = 1
saver = tf.train.Saver()
with tf.Session() as sess:
    
    # TODO: Your training code here
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for x, y in get_batches(train_x, train_y):
            loss, _ = sess.run([cost, optimizer], feed_dict={inputs_: x, labels_: y})
            print("Epoch: {}/{}".format(e+1, epochs),
                  "Iteration: {}".format(iteration),
                  "Training Loss: {:.4f}".format(loss))
            
            if iteration % 5 == 0:
                val_acc = sess.run(accuracy, feed_dict={inputs_: val_x, labels_: val_y})
                print("Epoch: {}/{}".format(e+1, epochs),
                      "Iteration: {}".format(iteration),
                      "Validation Accuracy: {:.4f}".format(val_acc))
            iteration += 1
                
    saver.save(sess, "checkpoints/sodabrands.ckpt")
# Out:
# Epoch: 1/20 Iteration: 1 Training Loss: 2.9705
# Epoch: 1/20 Iteration: 2 Training Loss: 3.1887
# Epoch: 1/20 Iteration: 3 Training Loss: 3.5766
# Epoch: 1/20 Iteration: 4 Training Loss: 4.4198
# Epoch: 1/20 Iteration: 5 Training Loss: 6.4250
# Epoch: 1/20 Iteration: 5 Validation Accuracy: 0.7280
# Epoch: 1/20 Iteration: 6 Training Loss: 3.3530
# Epoch: 1/20 Iteration: 7 Training Loss: 3.6267
# Epoch: 1/20 Iteration: 8 Training Loss: 3.9103
# Epoch: 1/20 Iteration: 9 Training Loss: 3.2908
# Epoch: 1/20 Iteration: 10 Training Loss: 1.3204
# Epoch: 1/20 Iteration: 10 Validation Accuracy: 0.6720
# Epoch: 2/20 Iteration: 11 Training Loss: 0.1384
# Epoch: 2/20 Iteration: 12 Training Loss: 1.1232
# Epoch: 2/20 Iteration: 13 Training Loss: 1.0525
# Epoch: 2/20 Iteration: 14 Training Loss: 0.4796
# Epoch: 2/20 Iteration: 15 Training Loss: 0.9963
# Epoch: 2/20 Iteration: 15 Validation Accuracy: 0.7360
# Epoch: 2/20 Iteration: 16 Training Loss: 0.9336
# Epoch: 2/20 Iteration: 17 Training Loss: 0.7687
# Epoch: 2/20 Iteration: 18 Training Loss: 1.8028
# Epoch: 2/20 Iteration: 19 Training Loss: 0.3479
# Epoch: 2/20 Iteration: 20 Training Loss: 0.3801
# Epoch: 2/20 Iteration: 20 Validation Accuracy: 0.6400
# Epoch: 3/20 Iteration: 21 Training Loss: 0.3638
# Epoch: 3/20 Iteration: 22 Training Loss: 0.8767
# Epoch: 3/20 Iteration: 23 Training Loss: 0.5658
# Epoch: 3/20 Iteration: 24 Training Loss: 0.4671
# Epoch: 3/20 Iteration: 25 Training Loss: 1.0576
# Epoch: 3/20 Iteration: 25 Validation Accuracy: 0.7120
# Epoch: 3/20 Iteration: 26 Training Loss: 0.4087
# Epoch: 3/20 Iteration: 27 Training Loss: 0.1255
# Epoch: 3/20 Iteration: 28 Training Loss: 0.3907
# Epoch: 3/20 Iteration: 29 Training Loss: 0.1547
# Epoch: 3/20 Iteration: 30 Training Loss: 0.9771
# Epoch: 3/20 Iteration: 30 Validation Accuracy: 0.6960
# Epoch: 4/20 Iteration: 31 Training Loss: 0.3576
# Epoch: 4/20 Iteration: 32 Training Loss: 0.4571
# Epoch: 4/20 Iteration: 33 Training Loss: 0.1795
# Epoch: 4/20 Iteration: 34 Training Loss: 0.0381
# Epoch: 4/20 Iteration: 35 Training Loss: 0.0377
# Epoch: 4/20 Iteration: 35 Validation Accuracy: 0.7120
# Epoch: 4/20 Iteration: 36 Training Loss: 0.1259
# Epoch: 4/20 Iteration: 37 Training Loss: 0.1649
# Epoch: 4/20 Iteration: 38 Training Loss: 0.5355
# Epoch: 4/20 Iteration: 39 Training Loss: 0.3491
# Epoch: 4/20 Iteration: 40 Training Loss: 0.0752
# Epoch: 4/20 Iteration: 40 Validation Accuracy: 0.7360
# Epoch: 5/20 Iteration: 41 Training Loss: 0.0018
# Epoch: 5/20 Iteration: 42 Training Loss: 0.0095
# Epoch: 5/20 Iteration: 43 Training Loss: 0.0174
# Epoch: 5/20 Iteration: 44 Training Loss: 0.0431
# Epoch: 5/20 Iteration: 45 Training Loss: 0.1362
# Epoch: 5/20 Iteration: 45 Validation Accuracy: 0.7280
# Epoch: 5/20 Iteration: 46 Training Loss: 0.1600
# Epoch: 5/20 Iteration: 47 Training Loss: 0.0397
# Epoch: 5/20 Iteration: 48 Training Loss: 0.0492
# Epoch: 5/20 Iteration: 49 Training Loss: 0.0631
# Epoch: 5/20 Iteration: 50 Training Loss: 0.0173
# Epoch: 5/20 Iteration: 50 Validation Accuracy: 0.7680
# Epoch: 6/20 Iteration: 51 Training Loss: 0.0030
# Epoch: 6/20 Iteration: 52 Training Loss: 0.0078
# Epoch: 6/20 Iteration: 53 Training Loss: 0.0099
# Epoch: 6/20 Iteration: 54 Training Loss: 0.0034
# Epoch: 6/20 Iteration: 55 Training Loss: 0.0104
# Epoch: 6/20 Iteration: 55 Validation Accuracy: 0.7680
# Epoch: 6/20 Iteration: 56 Training Loss: 0.0136
# Epoch: 6/20 Iteration: 57 Training Loss: 0.0203
# Epoch: 6/20 Iteration: 58 Training Loss: 0.0196
# Epoch: 6/20 Iteration: 59 Training Loss: 0.0143
# Epoch: 6/20 Iteration: 60 Training Loss: 0.0125
# Epoch: 6/20 Iteration: 60 Validation Accuracy: 0.7440
# Epoch: 7/20 Iteration: 61 Training Loss: 0.0023
# Epoch: 7/20 Iteration: 62 Training Loss: 0.0033
# Epoch: 7/20 Iteration: 63 Training Loss: 0.0095
# Epoch: 7/20 Iteration: 64 Training Loss: 0.0021
# Epoch: 7/20 Iteration: 65 Training Loss: 0.0081
# Epoch: 7/20 Iteration: 65 Validation Accuracy: 0.7440
# Epoch: 7/20 Iteration: 66 Training Loss: 0.0135
# Epoch: 7/20 Iteration: 67 Training Loss: 0.0164
# Epoch: 7/20 Iteration: 68 Training Loss: 0.0124
# Epoch: 7/20 Iteration: 69 Training Loss: 0.0081
# Epoch: 7/20 Iteration: 70 Training Loss: 0.0037
# Epoch: 7/20 Iteration: 70 Validation Accuracy: 0.7440
# Epoch: 8/20 Iteration: 71 Training Loss: 0.0009
# Epoch: 8/20 Iteration: 72 Training Loss: 0.0019
# Epoch: 8/20 Iteration: 73 Training Loss: 0.0026
# Epoch: 8/20 Iteration: 74 Training Loss: 0.0010
# Epoch: 8/20 Iteration: 75 Training Loss: 0.0038
# Epoch: 8/20 Iteration: 75 Validation Accuracy: 0.7520
# Epoch: 8/20 Iteration: 76 Training Loss: 0.0165
# Epoch: 8/20 Iteration: 77 Training Loss: 0.0071
# Epoch: 8/20 Iteration: 78 Training Loss: 0.0064
# Epoch: 8/20 Iteration: 79 Training Loss: 0.0047
# Epoch: 8/20 Iteration: 80 Training Loss: 0.0021
# Epoch: 8/20 Iteration: 80 Validation Accuracy: 0.7520
# Epoch: 9/20 Iteration: 81 Training Loss: 0.0005
# Epoch: 9/20 Iteration: 82 Training Loss: 0.0018
# Epoch: 9/20 Iteration: 83 Training Loss: 0.0022
# Epoch: 9/20 Iteration: 84 Training Loss: 0.0010
# Epoch: 9/20 Iteration: 85 Training Loss: 0.0036
# Epoch: 9/20 Iteration: 85 Validation Accuracy: 0.7520
# Epoch: 9/20 Iteration: 86 Training Loss: 0.0164
# Epoch: 9/20 Iteration: 87 Training Loss: 0.0049
# Epoch: 9/20 Iteration: 88 Training Loss: 0.0058
# Epoch: 9/20 Iteration: 89 Training Loss: 0.0049
# Epoch: 9/20 Iteration: 90 Training Loss: 0.0017
# Epoch: 9/20 Iteration: 90 Validation Accuracy: 0.7520
# Epoch: 10/20 Iteration: 91 Training Loss: 0.0004
# Epoch: 10/20 Iteration: 92 Training Loss: 0.0013
# Epoch: 10/20 Iteration: 93 Training Loss: 0.0016
# Epoch: 10/20 Iteration: 94 Training Loss: 0.0008
# Epoch: 10/20 Iteration: 95 Training Loss: 0.0028
# Epoch: 10/20 Iteration: 95 Validation Accuracy: 0.7520
# Epoch: 10/20 Iteration: 96 Training Loss: 0.0135
# Epoch: 10/20 Iteration: 97 Training Loss: 0.0039
# Epoch: 10/20 Iteration: 98 Training Loss: 0.0066
# Epoch: 10/20 Iteration: 99 Training Loss: 0.0060
# Epoch: 10/20 Iteration: 100 Training Loss: 0.0015
# Epoch: 10/20 Iteration: 100 Validation Accuracy: 0.7600
# Epoch: 11/20 Iteration: 101 Training Loss: 0.0003
# Epoch: 11/20 Iteration: 102 Training Loss: 0.0009
# Epoch: 11/20 Iteration: 103 Training Loss: 0.0012
# Epoch: 11/20 Iteration: 104 Training Loss: 0.0006
# Epoch: 11/20 Iteration: 105 Training Loss: 0.0021
# Epoch: 11/20 Iteration: 105 Validation Accuracy: 0.7600
# Epoch: 11/20 Iteration: 106 Training Loss: 0.0122
# Epoch: 11/20 Iteration: 107 Training Loss: 0.0033
# Epoch: 11/20 Iteration: 108 Training Loss: 0.0066
# Epoch: 11/20 Iteration: 109 Training Loss: 0.0061
# Epoch: 11/20 Iteration: 110 Training Loss: 0.0013
# Epoch: 11/20 Iteration: 110 Validation Accuracy: 0.7600
# Epoch: 12/20 Iteration: 111 Training Loss: 0.0003
# Epoch: 12/20 Iteration: 112 Training Loss: 0.0007
# Epoch: 12/20 Iteration: 113 Training Loss: 0.0009
# Epoch: 12/20 Iteration: 114 Training Loss: 0.0005
# Epoch: 12/20 Iteration: 115 Training Loss: 0.0018
# Epoch: 12/20 Iteration: 115 Validation Accuracy: 0.7600
# Epoch: 12/20 Iteration: 116 Training Loss: 0.0129
# Epoch: 12/20 Iteration: 117 Training Loss: 0.0028
# Epoch: 12/20 Iteration: 118 Training Loss: 0.0058
# Epoch: 12/20 Iteration: 119 Training Loss: 0.0054
# Epoch: 12/20 Iteration: 120 Training Loss: 0.0011
# Epoch: 12/20 Iteration: 120 Validation Accuracy: 0.7600
# Epoch: 13/20 Iteration: 121 Training Loss: 0.0002
# Epoch: 13/20 Iteration: 122 Training Loss: 0.0006
# Epoch: 13/20 Iteration: 123 Training Loss: 0.0008
# Epoch: 13/20 Iteration: 124 Training Loss: 0.0005
# Epoch: 13/20 Iteration: 125 Training Loss: 0.0015
# Epoch: 13/20 Iteration: 125 Validation Accuracy: 0.7600
# Epoch: 13/20 Iteration: 126 Training Loss: 0.0136
# Epoch: 13/20 Iteration: 127 Training Loss: 0.0025
# Epoch: 13/20 Iteration: 128 Training Loss: 0.0053
# Epoch: 13/20 Iteration: 129 Training Loss: 0.0050
# Epoch: 13/20 Iteration: 130 Training Loss: 0.0010
# Epoch: 13/20 Iteration: 130 Validation Accuracy: 0.7600
# Epoch: 14/20 Iteration: 131 Training Loss: 0.0002
# Epoch: 14/20 Iteration: 132 Training Loss: 0.0006
# Epoch: 14/20 Iteration: 133 Training Loss: 0.0007
# Epoch: 14/20 Iteration: 134 Training Loss: 0.0004
# Epoch: 14/20 Iteration: 135 Training Loss: 0.0013
# Epoch: 14/20 Iteration: 135 Validation Accuracy: 0.7600
# Epoch: 14/20 Iteration: 136 Training Loss: 0.0132
# Epoch: 14/20 Iteration: 137 Training Loss: 0.0022
# Epoch: 14/20 Iteration: 138 Training Loss: 0.0062
# Epoch: 14/20 Iteration: 139 Training Loss: 0.0060
# Epoch: 14/20 Iteration: 140 Training Loss: 0.0009
# Epoch: 14/20 Iteration: 140 Validation Accuracy: 0.7520
# Epoch: 15/20 Iteration: 141 Training Loss: 0.0002
# Epoch: 15/20 Iteration: 142 Training Loss: 0.0005
# Epoch: 15/20 Iteration: 143 Training Loss: 0.0006
# Epoch: 15/20 Iteration: 144 Training Loss: 0.0004
# Epoch: 15/20 Iteration: 145 Training Loss: 0.0011
# Epoch: 15/20 Iteration: 145 Validation Accuracy: 0.7600
# Epoch: 15/20 Iteration: 146 Training Loss: 0.0138
# Epoch: 15/20 Iteration: 147 Training Loss: 0.0019
# Epoch: 15/20 Iteration: 148 Training Loss: 0.0056
# Epoch: 15/20 Iteration: 149 Training Loss: 0.0054
# Epoch: 15/20 Iteration: 150 Training Loss: 0.0008
# Epoch: 15/20 Iteration: 150 Validation Accuracy: 0.7520
# Epoch: 16/20 Iteration: 151 Training Loss: 0.0002
# Epoch: 16/20 Iteration: 152 Training Loss: 0.0005
# Epoch: 16/20 Iteration: 153 Training Loss: 0.0006
# Epoch: 16/20 Iteration: 154 Training Loss: 0.0004
# Epoch: 16/20 Iteration: 155 Training Loss: 0.0010
# Epoch: 16/20 Iteration: 155 Validation Accuracy: 0.7600
# Epoch: 16/20 Iteration: 156 Training Loss: 0.0145
# Epoch: 16/20 Iteration: 157 Training Loss: 0.0017
# Epoch: 16/20 Iteration: 158 Training Loss: 0.0049
# Epoch: 16/20 Iteration: 159 Training Loss: 0.0048
# Epoch: 16/20 Iteration: 160 Training Loss: 0.0007
# Epoch: 16/20 Iteration: 160 Validation Accuracy: 0.7520
# Epoch: 17/20 Iteration: 161 Training Loss: 0.0002
# Epoch: 17/20 Iteration: 162 Training Loss: 0.0004
# Epoch: 17/20 Iteration: 163 Training Loss: 0.0005
# Epoch: 17/20 Iteration: 164 Training Loss: 0.0003
# Epoch: 17/20 Iteration: 165 Training Loss: 0.0009
# Epoch: 17/20 Iteration: 165 Validation Accuracy: 0.7440
# Epoch: 17/20 Iteration: 166 Training Loss: 0.0136
# Epoch: 17/20 Iteration: 167 Training Loss: 0.0015
# Epoch: 17/20 Iteration: 168 Training Loss: 0.0053
# Epoch: 17/20 Iteration: 169 Training Loss: 0.0052
# Epoch: 17/20 Iteration: 170 Training Loss: 0.0007
# Epoch: 17/20 Iteration: 170 Validation Accuracy: 0.7520
# Epoch: 18/20 Iteration: 171 Training Loss: 0.0002
# Epoch: 18/20 Iteration: 172 Training Loss: 0.0004
# Epoch: 18/20 Iteration: 173 Training Loss: 0.0005
# Epoch: 18/20 Iteration: 174 Training Loss: 0.0003
# Epoch: 18/20 Iteration: 175 Training Loss: 0.0008
# Epoch: 18/20 Iteration: 175 Validation Accuracy: 0.7440
# Epoch: 18/20 Iteration: 176 Training Loss: 0.0133
# Epoch: 18/20 Iteration: 177 Training Loss: 0.0014
# Epoch: 18/20 Iteration: 178 Training Loss: 0.0053
# Epoch: 18/20 Iteration: 179 Training Loss: 0.0052
# Epoch: 18/20 Iteration: 180 Training Loss: 0.0006
# Epoch: 18/20 Iteration: 180 Validation Accuracy: 0.7440
# Epoch: 19/20 Iteration: 181 Training Loss: 0.0001
# Epoch: 19/20 Iteration: 182 Training Loss: 0.0004
# Epoch: 19/20 Iteration: 183 Training Loss: 0.0004
# Epoch: 19/20 Iteration: 184 Training Loss: 0.0003
# Epoch: 19/20 Iteration: 185 Training Loss: 0.0008
# Epoch: 19/20 Iteration: 185 Validation Accuracy: 0.7520
# Epoch: 19/20 Iteration: 186 Training Loss: 0.0136
# Epoch: 19/20 Iteration: 187 Training Loss: 0.0012
# Epoch: 19/20 Iteration: 188 Training Loss: 0.0051
# Epoch: 19/20 Iteration: 189 Training Loss: 0.0051
# Epoch: 19/20 Iteration: 190 Training Loss: 0.0005
# Epoch: 19/20 Iteration: 190 Validation Accuracy: 0.7520
# Epoch: 20/20 Iteration: 191 Training Loss: 0.0001
# Epoch: 20/20 Iteration: 192 Training Loss: 0.0003
# Epoch: 20/20 Iteration: 193 Training Loss: 0.0004
# Epoch: 20/20 Iteration: 194 Training Loss: 0.0003
# Epoch: 20/20 Iteration: 195 Training Loss: 0.0007
# Epoch: 20/20 Iteration: 195 Validation Accuracy: 0.7520
# Epoch: 20/20 Iteration: 196 Training Loss: 0.0137
# Epoch: 20/20 Iteration: 197 Training Loss: 0.0011
# Epoch: 20/20 Iteration: 198 Training Loss: 0.0050
# Epoch: 20/20 Iteration: 199 Training Loss: 0.0050
# Epoch: 20/20 Iteration: 200 Training Loss: 0.0005
# Epoch: 20/20 Iteration: 200 Validation Accuracy: 0.7520

# %% [markdown]
# ### Testing
#
# Below you see the test accuracy. You can also see the predictions returned for images.

# %%
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: test_x,
            labels_: test_y}
    test_acc = sess.run(accuracy, feed_dict=feed)
    print("Test accuracy: {:.4f}".format(test_acc))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\sodabrands.ckpt
# Test accuracy: 0.7840

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from scipy.ndimage import imread

# %% [markdown]
# Below, feel free to choose images and see how the trained classifier predicts the soda brands in them.

# %%
test_img_path = 'outras_fotos/guarana.jpg'
test_img = imread(test_img_path)
plt.imshow(test_img)
# Out:
# C:\Users\Falamarcao\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   """

# %%
# Run this cell if you don't have a vgg graph built
if 'vgg' in globals():
    print('"vgg" object already exists.  Will not create again.')
else:
    #create vgg
    with tf.Session() as sess:
        input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
        vgg = vgg16.Vgg16()
        vgg.build(input_)
# Out:
# "vgg" object already exists.  Will not create again.

# %%
with tf.Session() as sess:
    img = utils.load_image(test_img_path)
    img = img.reshape((1, 224, 224, 3))

    feed_dict = {input_: img}
    code = sess.run(vgg.relu6, feed_dict=feed_dict)
        
saver = tf.train.Saver()
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: code}
    prediction = sess.run(predicted, feed_dict=feed).squeeze()
# Out:
# C:\Users\Falamarcao\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO:tensorflow:Restoring parameters from checkpoints\sodabrands.ckpt

# %%
plt.imshow(test_img)

# %%
plt.barh(np.arange(3), prediction)
_ = plt.yticks(np.arange(3), lb.classes_)

# %% [markdown]
# --------------------------------

# %%
test_img_path = 'outras_fotos/coca.jpg'
test_img = imread(test_img_path)
plt.imshow(test_img)
# Out:
# C:\Users\Falamarcao\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.

# %%
with tf.Session() as sess:
    img = utils.load_image(test_img_path)
    img = img.reshape((1, 224, 224, 3))

    feed_dict = {input_: img}
    code = sess.run(vgg.relu6, feed_dict=feed_dict)
        
saver = tf.train.Saver()
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: code}
    prediction = sess.run(predicted, feed_dict=feed).squeeze()
# Out:
# C:\Users\Falamarcao\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO:tensorflow:Restoring parameters from checkpoints\sodabrands.ckpt

# %%
plt.imshow(test_img)

# %%
plt.barh(np.arange(3), prediction)
_ = plt.yticks(np.arange(3), lb.classes_)

# %%
test_img_path = 'outras_fotos/coca_life.jpg'
test_img = imread(test_img_path)
plt.imshow(test_img)
# Out:
# C:\Users\Falamarcao\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.

# %%
with tf.Session() as sess:
    img = utils.load_image(test_img_path)
    img = img.reshape((1, 224, 224, 3))

    feed_dict = {input_: img}
    code = sess.run(vgg.relu6, feed_dict=feed_dict)
        
saver = tf.train.Saver()
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: code}
    prediction = sess.run(predicted, feed_dict=feed).squeeze()
# Out:
# C:\Users\Falamarcao\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO:tensorflow:Restoring parameters from checkpoints\sodabrands.ckpt

# %%
plt.imshow(test_img)

# %%
plt.barh(np.arange(3), prediction)
_ = plt.yticks(np.arange(3), lb.classes_)

# %%
test_img_path = 'outras_fotos/pepsi2.jpg'
test_img = imread(test_img_path)
plt.imshow(test_img)
# Out:
# C:\Users\Falamarcao\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.

# %%
with tf.Session() as sess:
    img = utils.load_image(test_img_path)
    img = img.reshape((1, 224, 224, 3))

    feed_dict = {input_: img}
    code = sess.run(vgg.relu6, feed_dict=feed_dict)
        
saver = tf.train.Saver()
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: code}
    prediction = sess.run(predicted, feed_dict=feed).squeeze()
# Out:
# C:\Users\Falamarcao\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO:tensorflow:Restoring parameters from checkpoints\sodabrands.ckpt

# %%
plt.imshow(test_img)

# %%
plt.barh(np.arange(3), prediction)
_ = plt.yticks(np.arange(3), lb.classes_)

# %%
test_img_path = 'outras_fotos/guarana (1).jpg'
test_img = imread(test_img_path)
plt.imshow(test_img)
# Out:
# C:\Users\Falamarcao\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.

# %%
with tf.Session() as sess:
    img = utils.load_image(test_img_path)
    img = img.reshape((1, 224, 224, 3))

    feed_dict = {input_: img}
    code = sess.run(vgg.relu6, feed_dict=feed_dict)
        
saver = tf.train.Saver()
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: code}
    prediction = sess.run(predicted, feed_dict=feed).squeeze()
# Out:
# C:\Users\Falamarcao\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO:tensorflow:Restoring parameters from checkpoints\sodabrands.ckpt

# %%
plt.imshow(test_img)

# %%
plt.barh(np.arange(3), prediction)
_ = plt.yticks(np.arange(3), lb.classes_)
